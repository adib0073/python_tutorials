# %% [markdown]
# <a href="https://colab.research.google.com/github/adib0073/python_tutorials/blob/main/Python_Pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Tutorial: Working with Pandas DataFrame

# %% [markdown]
# ### AGENDA:
#
# 1. Basics of Pandas
#    - Introduction
#    - Getting Started
#    - Pandas Series
#    - DataFrames
#    - CSV Datasets
#    - Data Analysis
#
# 2. Data analysis using Pandas operations
#    - Descriptive statistics
#    - Data preparation before predictive modeling
#    - Basic data visualizations

# %% [markdown]
# #### 1.1: Introduction

# %% [markdown]
# ### What is Pandas?
#
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008
#
# Pandas project on GitHub: https://github.com/pandas-dev/pandas

# %% [markdown]
# ### 1.2 Getting Started

# %%
# If installation is required, please use: !pip install pandas

# %%
import pandas

# %%
print(pandas.__version__)
# Out:
# 2.0.3

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 10.0]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW       3.0
# 1  Volvo       7.0
# 2   Ford      10.0

# %%
# Generally it is imported as "pd"
import pandas as pd

# %%
type(myvar)
# Out:
# pandas.core.frame.DataFrame

# %%
myvar['cars'].dtype
# Out:
# dtype('O')

# %%
myvar.head() # View top 5
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
myvar.tail() # View last 5
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
myvar.head(2) # View only top 2 items
# Out:
#     cars  passings
# 0    BMW       3.0
# 1  Volvo       7.0

# %% [markdown]
# ### 1.3 Pandas series
#
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
myvar.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
type(myvar)
# Out:
# pandas.core.series.Series

# %%
# Return first value of the series
print(myvar[0])
# Out:
# 1

# %%
len(myvar)
# Out:
# 3

# %%
# Series with Index
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
myvar["x"]
# Out:
# 1

# %%
myvar.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
myvar.reset_index()
# Out:
#   index  0
# 0     x  1
# 1     y  7
# 2     z  2

# %%
type(myvar)
# Out:
# pandas.core.series.Series

# %%
myvar.reindex(index=['x', 'y', 'z']) #set_index()
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["y"])
# Out:
# 7

# %%
# Will this work now? print(myvar[0])

# %%
print(myvar[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-78b6590decae> in <cell line: 1>()
# ----> 1 print(myvar[0])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 10.0]
}

df_1 = pd.DataFrame(mydataset)

df_1.head()
# Out:
#     cars  passings
# 0    BMW       3.0
# 1  Volvo       7.0
# 2   Ford      10.0

# %%
type(df_1.cars.values)
# Out:
# numpy.ndarray

# %%
list(df_1.cars.values)
# Out:
# ['BMW', 'Volvo', 'Ford']

# %%
pd.Series(df_1.cars.values, index = ["x", "y", "z"])
# Out:
# x      BMW
# y    Volvo
# z     Ford
# dtype: object

# %%
# Pandas series from a dictionary
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
# With selected index
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ### 1.4 Pandas DataFrame
#
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.head()
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.shape
# Out:
# (3, 2)

# %%
df.columns
# Out:
# Index(['calories', 'duration'], dtype='object')

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[0,1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
pd.DataFrame([[1, 2, 3], [4, 5, 6]], columns = ["A", "B", "C"])
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
#refer to the named index:
print(df.loc["day3"])
# Out:
# calories    390
# duration     45
# Name: day3, dtype: int64

# %% [markdown]
# ### CSV Data with Pandas

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# 5       671.0       239.0         3.3438             74000.0
# 6      1841.0       633.0         2.6768             82400.0
# 7       375.0       158.0         1.7083             48500.0
# 8      3134.0      1056.0         2.1782             58400.0
# 9       787.0       271.0         2.1908             48100.0

# %%
len(df) == 0
# Out:
# False

# %%
# Read JSON data
df = pd.read_json('/content/sample_data/anscombe.json')

# %%
df.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5": 350
  }
}

df = pd.DataFrame(data)

df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
### Analysing data using Pandas

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  6 non-null      int64
#  1   Pulse     6 non-null      int64
#  2   Maxpulse  6 non-null      int64
#  3   Calories  6 non-null      int64
# dtypes: int64(4)
# memory usage: 240.0+ bytes
# None

# %%
df.describe() # Descriptive Analytics
# Out:
#         Duration       Pulse    Maxpulse    Calories
# count   6.000000    6.000000    6.000000    6.000000
# mean   55.000000  109.666667  143.333333  377.666667
# std     7.745967    6.501282   17.557525   68.394932
# min    45.000000  102.000000  127.000000  282.000000
# 25%    48.750000  104.500000  131.250000  342.500000
# 50%    60.000000  109.500000  140.000000  378.000000
# 75%    60.000000  115.250000  147.250000  408.250000
# max    60.000000  117.000000  175.000000  479.000000

# %%
df_url = pd.read_csv('https://raw.githubusercontent.com/adib0073/FastAPI_Docker_Deployment/main/uci_heart_disease/Data/heart.csv')

# %%
df_url.head()
# Out:
#    age  sex  chest_pain_type  resting_bp  cholestoral  fasting_blood_sugar  \
# 0   63    1                3         145          233                    1
# 1   37    1                2         130          250                    0
# 2   41    0                1         130          204                    0
# 3   56    1                1         120          236                    0
# 4   57    0                0         120          354                    0
#
#    restecg  max_hr  exang  oldpeak  slope  num_major_vessels  thal  target
# 0        0     150      0      2.3      0                  0     1       1
# 1        1     187      0      3.5      0                  0     2       1
# 2        0     172      0      1.4      2                  0     2       1
# 3        1     178      0      0.8      2                  0     2       1
# 4        1     163      1      0.6      2                  0     2       1

# %%
df_url.shape
# Out:
# (303, 14)

# %%
df_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  303 non-null    int64
#  1   sex                  303 non-null    int64
#  2   chest_pain_type      303 non-null    int64
#  3   resting_bp           303 non-null    int64
#  4   cholestoral          303 non-null    int64
#  5   fasting_blood_sugar  303 non-null    int64
#  6   restecg              303 non-null    int64
#  7   max_hr               303 non-null    int64
#  8   exang                303 non-null    int64
#  9   oldpeak              303 non-null    float64
#  10  slope                303 non-null    int64
#  11  num_major_vessels    303 non-null    int64
#  12  thal                 303 non-null    int64
#  13  target               303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df_url['sex'].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
for column in df_url.columns:
  print(df_url[column].value_counts())
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 60    11
# 44    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 65     8
# 43     8
# 45     8
# 55     8
# 42     8
# 61     8
# 53     8
# 46     7
# 48     7
# 66     7
# 50     7
# 49     5
# 47     5
# 70     4
# 39     4
# 35     4
# 68     4
# 38     3
# 71     3
# 40     3
# 69     3
# 34     2
# 37     2
# 29     1
# 74     1
# 76     1
# 77     1
# Name: count, dtype: int64
# sex
# 1    207
# 0     96
# Name: count, dtype: int64
# chest_pain_type
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64
# resting_bp
# 120    37
# 130    36
# 140    32
# 110    19
# 150    17
# 138    13
# 128    12
# 160    11
# 125    11
# 112     9
# 132     8
# 118     7
# 124     6
# 135     6
# 108     6
# 152     5
# 134     5
# 145     5
# 122     4
# 170     4
# 100     4
# 105     3
# 126     3
# 115     3
# 180     3
# 136     3
# 142     3
# 102     2
# 148     2
# 178     2
# 94      2
# 144     2
# 146     2
# 200     1
# 114     1
# 154     1
# 123     1
# 192     1
# 174     1
# 165     1
# 104     1
# 117     1
# 101     1
# 156     1
# 106     1
# 155     1
# 129     1
# 172     1
# 164     1
# Name: count, dtype: int64
# cholestoral
# 204    6
# 197    6
# 234    6
# 269    5
# 254    5
#       ..
# 284    1
# 224    1
# 167    1
# 276    1
# 131    1
# Name: count, Length: 152, dtype: int64
# fasting_blood_sugar
# 0    258
# 1     45
# Name: count, dtype: int64
# restecg
# 1    152
# 0    147
# 2      4
# Name: count, dtype: int64
# max_hr
# 162    11
# 160     9
# 163     9
# 152     8
# 173     8
#        ..
# 202     1
# 184     1
# 121     1
# 192     1
# 90      1
# Name: count, Length: 91, dtype: int64
# exang
# 0    204
# 1     99
# Name: count, dtype: int64
# oldpeak
# 0.0    99
# 1.2    17
# 1.0    14
# 0.6    14
# 1.4    13
# 0.8    13
# 0.2    12
# 1.6    11
# 1.8    10
# 0.4     9
# 2.0     9
# 0.1     7
# 2.8     6
# 2.6     6
# 1.5     5
# 3.0     5
# 1.9     5
# 0.5     5
# 3.6     4
# 2.2     4
# 2.4     3
# 0.9     3
# 3.4     3
# 4.0     3
# 0.3     3
# 2.3     2
# 3.2     2
# 2.5     2
# 4.2     2
# 1.1     2
# 3.1     1
# 0.7     1
# 3.5     1
# 6.2     1
# 1.3     1
# 5.6     1
# 2.9     1
# 2.1     1
# 3.8     1
# 4.4     1
# Name: count, dtype: int64
# slope
# 2    142
# 1    140
# 0     21
# Name: count, dtype: int64
# num_major_vessels
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: count, dtype: int64
# thal
# 2    166
# 3    117
# 1     18
# 0      2
# Name: count, dtype: int64
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
categories = ["sex", "chest_pain_type", "slope"]
numerical = ["age", "max_hr", "resting_bp", "cholestoral"]

# %%
df_url[numerical].describe()
# Out:
#               age      max_hr  resting_bp  cholestoral
# count  303.000000  303.000000  303.000000   303.000000
# mean    54.366337  149.646865  131.623762   246.264026
# std      9.082101   22.905161   17.538143    51.830751
# min     29.000000   71.000000   94.000000   126.000000
# 25%     47.500000  133.500000  120.000000   211.000000
# 50%     55.000000  153.000000  130.000000   240.000000
# 75%     61.000000  166.000000  140.000000   274.500000
# max     77.000000  202.000000  200.000000   564.000000

# %%
df_describe = df_url[numerical].describe()

# %%
df_describe.head()
# Out:
#               age      max_hr  resting_bp  cholestoral
# count  303.000000  303.000000  303.000000   303.000000
# mean    54.366337  149.646865  131.623762   246.264026
# std      9.082101   22.905161   17.538143    51.830751
# min     29.000000   71.000000   94.000000   126.000000
# 25%     47.500000  133.500000  120.000000   211.000000

# %%
df_url.isnull().sum().any() # Checking Missing Values
# Out:
# False

# %%
df_url.duplicated().any() # Checking Duplicates
# Out:
# True

# %%
df_url.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Length: 303, dtype: bool

# %%
df_url.duplicated().sum() # Checking Count of Duplicates
# Out:
# 1

# %%
df_url.drop_duplicates(inplace=True) # df_url = df_url.drop_duplicates()

# %%
df_url.shape
# Out:
# (302, 14)

# %%
# df['cholesterol'] ->  function(input_var, threshold = 400) : df['outlier_chol'] = [False, False, ... , True, False ...]

# %%
def chol_check(val):
  thr= 400
  if val>thr:
    return True
  else:
    return False

df_url['outlier_chol'] = [chol_check(x) for x in df_url['cholestoral']]
print(df_url['outlier_chol'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Name: outlier_chol, Length: 303, dtype: bool

# %%
thr= 400
chol_check_lambda = lambda x : True if x > thr else False

df_url['outlier_chol'] = df_url['cholestoral'].apply(chol_check_lambda)

# %%
df_url.shape
# Out:
# (303, 15)

# %%
df_url['outlier_chol'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: outlier_chol, dtype: bool

# %%
df_url.groupby('sex')['target'].sum()
# Out:
# sex
# 0    72
# 1    93
# Name: target, dtype: int64

# %%
pd.pivot_table(data=df_url, index=['sex'])
# Out:
#            age  chest_pain_type  cholestoral     exang  fasting_blood_sugar  \
# sex
# 0    55.677083         1.041667   261.302083  0.229167              0.12500
# 1    53.758454         0.932367   239.289855  0.371981              0.15942
#
#          max_hr  num_major_vessels   oldpeak  outlier_chol   restecg  \
# sex
# 0    151.125000           0.552083  0.876042      0.041667  0.572917
# 1    148.961353           0.811594  1.115459      0.000000  0.507246
#
#      resting_bp     slope    target      thal
# sex
# 0    133.083333  1.427083  0.750000  2.125000
# 1    130.946860  1.386473  0.449275  2.400966

# %%
pd.pivot_table?

# %%
df_url[numerical]
# Out:
#      age  max_hr  resting_bp  cholestoral
# 0     63     150         145          233
# 1     37     187         130          250
# 2     41     172         130          204
# 3     56     178         120          236
# 4     57     163         120          354
# ..   ...     ...         ...          ...
# 298   57     123         140          241
# 299   45     132         110          264
# 300   68     141         144          193
# 301   57     115         130          131
# 302   57     174         130          236
#
# [303 rows x 4 columns]

# %%
df_url.query('sex == 1')
# Out:
#      age  sex  chest_pain_type  resting_bp  cholestoral  fasting_blood_sugar  \
# 0     63    1                3         145          233                    1
# 1     37    1                2         130          250                    0
# 3     56    1                1         120          236                    0
# 5     57    1                0         140          192                    0
# 7     44    1                1         120          263                    0
# ..   ...  ...              ...         ...          ...                  ...
# 295   63    1                0         140          187                    0
# 297   59    1                0         164          176                    1
# 299   45    1                3         110          264                    0
# 300   68    1                0         144          193                    1
# 301   57    1                0         130          131                    0
#
#      restecg  max_hr  exang  oldpeak  slope  num_major_vessels  thal  target  \
# 0          0     150      0      2.3      0                  0     1       1
# 1          1     187      0      3.5      0                  0     2       1
# 3          1     178      0      0.8      2                  0     2       1
# 5          1     148      0      0.4      1                  0     1       1
# 7          1     173      0      0.0      2                  0     3       1
# ..       ...     ...    ...      ...    ...                ...   ...     ...
# 295        0     144      1      4.0      2                  2     3       0
# 297        0      90      0      1.0      1                  2     1       0
# 299        1     132      0      1.2      1                  0     3       0
# 300        1     141      0      3.4      1                  2     3       0
# 301        1     115      1      1.2      1                  1     3       0
#
#      outlier_chol
# 0           False
# 1           False
# 3           False
# 5           False
# 7           False
# ..            ...
# 295         False
# 297         False
# 299         False
# 300         False
# 301         False
#
# [207 rows x 15 columns]

# %%
df_url[df_url['sex'] == 1]
# Out:
#      age  sex  chest_pain_type  resting_bp  cholestoral  fasting_blood_sugar  \
# 0     63    1                3         145          233                    1
# 1     37    1                2         130          250                    0
# 3     56    1                1         120          236                    0
# 5     57    1                0         140          192                    0
# 7     44    1                1         120          263                    0
# ..   ...  ...              ...         ...          ...                  ...
# 295   63    1                0         140          187                    0
# 297   59    1                0         164          176                    1
# 299   45    1                3         110          264                    0
# 300   68    1                0         144          193                    1
# 301   57    1                0         130          131                    0
#
#      restecg  max_hr  exang  oldpeak  slope  num_major_vessels  thal  target  \
# 0          0     150      0      2.3      0                  0     1       1
# 1          1     187      0      3.5      0                  0     2       1
# 3          1     178      0      0.8      2                  0     2       1
# 5          1     148      0      0.4      1                  0     1       1
# 7          1     173      0      0.0      2                  0     3       1
# ..       ...     ...    ...      ...    ...                ...   ...     ...
# 295        0     144      1      4.0      2                  2     3       0
# 297        0      90      0      1.0      1                  2     1       0
# 299        1     132      0      1.2      1                  0     3       0
# 300        1     141      0      3.4      1                  2     3       0
# 301        1     115      1      1.2      1                  1     3       0
#
#      outlier_chol
# 0           False
# 1           False
# 3           False
# 5           False
# 7           False
# ..            ...
# 295         False
# 297         False
# 299         False
# 300         False
# 301         False
#
# [207 rows x 15 columns]

# %%
pd.merge(df_1, df_2, how='inner')
